# %% [markdown]
#  ## <a id='0'> **1. ANÁLISIS EXPLORATORIO DE DATOS (EDA) - NFL 🏈** </a>
# ##### *THE BRIDGE - DATA_SCIENCE 2023*
#  <a id='0'> ![Cover](/Users/ivanlamb/Documents/GitHub/eda_nfl/src/img/Eda_cover.png)</h1>

# %% [markdown]
# ## <a id='1'> *ÍNDICE:* </a>
# ---
# - [1. Introducción:](#3)
#     - [1.1. Hipótesis](#11)
#     - [1.2. Limpieza de datos](5#)
#         - [1.2.1 ](44#)
#         - [1.2.3 Visualización](123#)
# - [2. Conclusiones](#4)

# %% [markdown]
# -----
# ####  *Contacto*:
# *Aquí podrás encontrar mi perfil personal*:
# -   [LinkedIn](https://www.linkedin.com/in/ivancorderoc/) ![LinkedIn](/Users/ivanlamb/Documents/GitHub/eda_nfl/src/img/linkedin.png)
#
# *Para dudas y consultas*:
# -   [Gmail](ivan.corderocueva@gmail.com) ![Gmail](/Users/ivanlamb/Documents/GitHub/eda_nfl/src/img/gmail.png)
#
# *Mi baúl con todos mis proyectos:
# -   [GitHub](https://github.com/ivancorderoc) ![GitHub](/Users/ivanlamb/Documents/GitHub/eda_nfl/src/img/github.png)
# -----

# %% [markdown]
# # <a id='3'>**1. Introducción**</a>

# %% [markdown]
# #### Este estudio se ha realizado gracias a una libreria dedica a la NFL y a Wikipedia.
#
# La idea fundamental del proyecto es dilucidar si el estar sano influye significativamnete en el éxito de jugador.
# Así como también si a pesar de esas lesiones su grado de desempeño en el campo le permite ser un jugador referente.

# %% [markdown]
#  ## <a id='4'> **1.1 Hipótesis.** </a>
#
# 1.  **¿Cuál es la relación entre lesiones y éxito en la NFL?**
# 2.  **¿Las consideras lesiones severas son las más habituales?**
# 3.  **¿Las lesiones leves pueden terminar con la carrera de los profesionales?**
# 4.  **¿En qué época de la temporada regular existen más lesiones?**
# 5.  **¿Cuál es la posición que tiende lesionarse?**
# 6.  **¿Qué hace la NFL para intentar reducir el número de lesiones para que no acaben con la carrera/vida de los jugadores? *(pregunta a futuro)***

# %% [markdown]
# ## <a id='4'> **1.1 Limpieza de datos.** </a>

# %% [markdown]
# ### ***Presentación de nuestros datasets***.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
from scipy.stats import chi2_contingency
warnings.filterwarnings("ignore")

# %%
# Asignamos variables a los datasets con los que vamos a trabajar.
ranks_nfl = pd.read_csv("/Users/ivanlamb/Documents/GitHub/eda_nfl/src/data/processed/ranks_nfl.csv")
injuries = pd.read_csv("/Users/ivanlamb/Documents/GitHub/eda_nfl/src/data/processed/injuries.csv")

# %%
ranks_nfl.head(10)
# Out:
#    Rank           Player       Position             2010 Team 2011 Team  \
# 0     1        Tom Brady    Quarterback  New England Patriots       NaN
# 1     2   Peyton Manning    Quarterback    Indianapolis Colts       NaN
# 2     3  Adrian Peterson   Running back     Minnesota Vikings       NaN
# 3     4        Ray Lewis     Linebacker      Baltimore Ravens       NaN
# 4     5          Ed Reed         Safety      Baltimore Ravens       NaN
# 5     6    Troy Polamalu         Safety   Pittsburgh Steelers       NaN
# 6     7    Andre Johnson  Wide receiver        Houston Texans       NaN
# 7     8   Darrelle Revis     Cornerback         New York Jets       NaN
# 8     9       Drew Brees    Quarterback    New Orleans Saints       NaN
# 9    10   Julius Peppers  Defensive end         Chicago Bears       NaN
#
#   Reference    Year 2012 Team Rank Change 2013 Team 2014 Team 2015 Team  \
# 0       1.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 1       2.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 2       3.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 3       4.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 4       5.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 5       6.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 6       7.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 7       8.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 8       9.0  2010.0       NaN         NaN       NaN       NaN       NaN
# 9       NaN  2010.0       NaN         NaN       NaN       NaN       NaN
#
#   2015 team 2016 team Rank change 2017 team Year accomplishments 2018 team  \
# 0       NaN       NaN         NaN       NaN                  NaN       NaN
# 1       NaN       NaN         NaN       NaN                  NaN       NaN
# 2       NaN       NaN         NaN       NaN                  NaN       NaN
# 3       NaN       NaN         NaN       NaN                  NaN       NaN
# 4       NaN       NaN         NaN       NaN                  NaN       NaN
# 5       NaN       NaN         NaN       NaN                  NaN       NaN
# 6       NaN       NaN         NaN       NaN                  NaN       NaN
# 7       NaN       NaN         NaN       NaN                  NaN       NaN
# 8       NaN       NaN         NaN       NaN                  NaN       NaN
# 9       NaN       NaN         NaN       NaN                  NaN       NaN
#
#   2019 team 2020 team
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
# 5       NaN       NaN
# 6       NaN       NaN
# 7       NaN       NaN
# 8       NaN       NaN
# 9       NaN       NaN

# %%
# Vemos la informacion que nos da el *primer dataset*
print(ranks_nfl.shape)
print(ranks_nfl.info())
# Out:
# (1000, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  1000 non-null   int64
#  1   Player                1000 non-null   object
#  2   Position              1000 non-null   object
#  3   2010 Team             100 non-null    object
#  4   2011 Team             108 non-null    object
#  5   Reference             974 non-null    object
#  6   Year                  1000 non-null   float64
#  7   2012 Team             105 non-null    object
#  8   Rank Change           400 non-null    object
#  9   2013 Team             111 non-null    object
#  10  2014 Team             106 non-null    object
#  11  2015 Team             9 non-null      object
#  12  2015 team             100 non-null    object
#  13  2016 team             105 non-null    object
#  14  Rank change           500 non-null    object
#  15  2017 team             103 non-null    object
#  16  Year accomplishments  370 non-null    object
#  17  2018 team             111 non-null    object
#  18  2019 team             110 non-null    object
#  19  2020 team             15 non-null     object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 156.4+ KB
# None

# %%
# Vemos los unicos de cada columna
print(ranks_nfl.nunique())
# Out:
# Rank                    100
# Player                  403
# Position                 20
# 2010 Team                30
# 2011 Team                34
# Reference               274
# Year                     10
# 2012 Team                32
# Rank Change              68
# 2013 Team                33
# 2014 Team                31
# 2015 Team                 8
# 2015 team                32
# 2016 team                30
# Rank change              68
# 2017 team                29
# Year accomplishments    303
# 2018 team                32
# 2019 team                33
# 2020 team                14
# dtype: int64

# %%
injuries.head(10)
# Out:
#    season game_type team  week     gsis_id position         full_name  \
# 0  2010.0       REG  ARI   1.0  00-0027007       RB       Chris Wells
# 1  2010.0       REG  ARI   1.0  00-0022288       RB      Jason Wright
# 2  2010.0       REG  ARI   1.0  00-0025668       CB     Michael Adams
# 3  2010.0       REG  ARI   1.0  00-0026939       LB        Will Davis
# 4  2010.0       REG  ARI   1.0  00-0022921       WR  Larry Fitzgerald
# 5  2010.0       REG  ARI   1.0  00-0025602       TE       Ben Patrick
# 6  2010.0       REG  ARI   1.0  00-0013126       LB       Joey Porter
# 7  2010.0       REG  ARI   1.0  00-0027691       WR     Andre Roberts
# 8  2010.0       REG  ATL   1.0  00-0022781       WR   Michael Jenkins
# 9  2010.0       REG  ATL   1.0  00-0024183       CB      Brent Grimes
#
#   first_name   last_name report_primary_injury report_secondary_injury  \
# 0      Chris       Wells                  Knee                     NaN
# 1      Jason      Wright                   Toe                     NaN
# 2    Michael       Adams              Shoulder                     NaN
# 3       Will       Davis                  Knee                     NaN
# 4      Larry  Fitzgerald                  Knee                     NaN
# 5        Ben     Patrick                  Knee                     NaN
# 6       Joey      Porter                  Back                     NaN
# 7      Andre     Roberts              Shoulder                     NaN
# 8    Michael     Jenkins              Shoulder                     NaN
# 9      Brent      Grimes                   Hip                     NaN
#
#   report_status practice_primary_injury practice_secondary_injury  \
# 0  Questionable                    Knee                       NaN
# 1  Questionable                     Toe                       NaN
# 2      Probable                Shoulder                       NaN
# 3      Probable                    Knee                       NaN
# 4      Probable                    Knee                       NaN
# 5      Probable                    Knee                       NaN
# 6      Probable                    Back                       NaN
# 7      Probable                Shoulder                       NaN
# 8           Out                Shoulder                       NaN
# 9  Questionable                     Hip                       NaN
#
#                      practice_status        date_modified
# 0    Did Not Participate In Practice  2010-09-10 12:13:53
# 1  Limited Participation in Practice  2010-09-10 12:13:44
# 2     Full Participation in Practice                  NaN
# 3     Full Participation in Practice                  NaN
# 4     Full Participation in Practice                  NaN
# 5     Full Participation in Practice                  NaN
# 6     Full Participation in Practice                  NaN
# 7     Full Participation in Practice                  NaN
# 8    Did Not Participate In Practice  2010-09-10 12:53:27
# 9     Full Participation in Practice  2010-09-10 12:52:50

# %%
# Vemos la informacion que nos da el *segundo* dataset*
print(injuries.shape)
print(injuries.info())
# Out:
# (51119, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51119 entries, 0 to 51118
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   season                     51119 non-null  float64
#  1   game_type                  51119 non-null  object
#  2   team                       51119 non-null  object
#  3   week                       51119 non-null  float64
#  4   gsis_id                    51119 non-null  object
#  5   position                   51119 non-null  object
#  6   full_name                  51119 non-null  object
#  7   first_name                 51119 non-null  object
#  8   last_name                  51119 non-null  object
#  9   report_primary_injury      39778 non-null  object
#  10  report_secondary_injury    2145 non-null   object
#  11  report_status              39778 non-null  object
#  12  practice_primary_injury    51074 non-null  object
#  13  practice_secondary_injury  2773 non-null   object
#  14  practice_status            51119 non-null  object
#  15  date_modified              51057 non-null  object
# dtypes: float64(2), object(14)
# memory usage: 6.2+ MB
# None

# %%
# Vemos los unicos de cada columna

print(injuries.nunique())
# Out:
# season                          10
# game_type                        5
# team                            34
# week                            21
# gsis_id                       4470
# position                        17
# full_name                     4416
# first_name                    1575
# last_name                     2522
# report_primary_injury          164
# report_secondary_injury        103
# report_status                    4
# practice_primary_injury        194
# practice_secondary_injury      130
# practice_status                  5
# date_modified                31553
# dtype: int64

# %% [markdown]
# ## *Limpieza de nuestros datasets.*
# -   ### Primer dataset:

# %%
# Eliminamos todas las columnas innecesarias y las organizamos.

ranks_nfl = ranks_nfl.reindex(columns=["Rank", "Player", "Position", "Year"])

# %%
# Cambiamos los nombres en nuestra columna "Position"

ranks_nfl["Position"].replace({"Wide Receiver":"Wide receiver",
                              "Fullback":"Running back",
                              "Strong safety":"Safety",
                              "Free safety":"Safety",
                              "Outside linebacker":"Linebacker",
                              "Offensive Tackle" :"Offensive tackle",
                              "Defensive Tackle":"Defensive tackle"}, inplace=True)

# %% [markdown]
# -   ### *Segundo dataset:*

# %%
# Procedemos a eliminar columnas que no son importantes y de paso estandarizamos varios los nombres de las columnas
injuries.drop(columns=["gsis_id", 
                       "first_name",
                       "last_name",
                       "report_secondary_injury",
                       "practice_secondary_injury",
                       "date_modified"],
              inplace=True)
injuries.rename(columns={'season':'Year',
                         'game_type':'Season',
                         'team':'Team',
                         'position':'Position',
                         'full_name': 'Player',
                         'week': 'Week'},
                inplace=True)

# %%
# eliminamos los valores faltantes y vemos como se va reduciendo nuestro dataset

injuries.dropna(inplace=True)
injuries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39733 entries, 0 to 51111
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     39733 non-null  float64
#  1   Season                   39733 non-null  object
#  2   Team                     39733 non-null  object
#  3   Week                     39733 non-null  float64
#  4   Position                 39733 non-null  object
#  5   Player                   39733 non-null  object
#  6   report_primary_injury    39733 non-null  object
#  7   report_status            39733 non-null  object
#  8   practice_primary_injury  39733 non-null  object
#  9   practice_status          39733 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 3.3+ MB

# %%
# Nos centraremos en jugadores que realmente están reportados como lesionados

injuries = injuries.loc[(injuries["practice_status"]== injuries["practice_status"].unique()[0]) | (injuries["practice_status"]== injuries["practice_status"].unique()[-1]) ]

# %%
# Nuestro análisis se centrará en la temporada regular

injuries = injuries[injuries["Season"].str.contains("REG")]

# %%
# Limpiamos la columna "Position"

injuries["Position"].replace({"LB":"Linebacker",
                              "WR":"Wide receiver",
                              "CB":"Cornerback",
                              "RB":"Running back",
                              "S":"Safety",
                              "DE":"Defense end",
                              "T":"Offensive tackle",
                              "DT":"Defensive tackle",
                              "TE": "Tight end",
                              "G": "Guard",
                              "QB":"Quarterback",
                              "C": "Center",
                              "K": "Kicker",
                              "P": "Punter",
                              "LS":"Long snapper",
                              "KR": "Kicker returner",
                              "PR":"Punt returner",}, inplace=True)

# %%
# Estandarizamos nuestras columnas para dejarlas en una categoría correspondiente.

injuries["report_primary_injury"].replace({"left Shoulder":"Shoulder",
                                   "right Shoulder":"Shoulder",
                                   "Right Shoulder":"Shoulder",
                                   "migraines":"Migraines",
                                   "(migraines)":"Migraines",
                                   "left Groin":"Groin",
                                   "right Groin":"Groin",
                                   "left Forearm":"Forearm",
                                   "right Knee":"Knee",
                                   "left Knee":"Knee",
                                   "right Finger":"Finger",
                                   "right hip":"Hip",
                                   "Quadricep":"Quadriceps",
                                   "right Quadricep":"Quadriceps",
                                   "rt. thumb":"Thumb",
                                   "right Thumb":"Thumb",
                                   "left Calf": "Calf",
                                   "right Calf": "Calf",
                                   "groin, knee, ankle": "Multiple",
                                   "Shoulder, Finger": "Multiple",
                                   "Bicep":"Biceps",
                                   "right Elbow": "Elbow",
                                   "Core": "Core Muscle",
                                   "Core Muscle Injury": "Core Muscle",
                                   "Right Collarbone": "Collarbone",
                                   "Medical Illness":"Illness",
                                   "left Wrist": "Wrist",
                                   "right Hamstring":"Hamstring",
                                   "Triceps":"Triceps",
                                   "right Hip":"Hip",}, inplace=True)


injuries["practice_primary_injury"].replace({"left Shoulder":"Shoulder",
                                   "right Shoulder":"Shoulder",
                                   "Right Shoulder":"Shoulder",
                                   "migraines":"Migraines",
                                   "(migraines)":"Migraines",
                                   "left Groin":"Groin",
                                   "right Groin":"Groin",
                                   "left Forearm":"Forearm",
                                   "right Knee":"Knee",
                                   "left Knee":"Knee",
                                   "right Finger":"Finger",
                                   "right hip":"Hip",
                                   "Quadricep":"Quadriceps",
                                   "right Quadricep":"Quadriceps",
                                   "rt. thumb":"Thumb",
                                   "right Thumb":"Thumb",
                                   "left Calf": "Calf",
                                   "right Calf": "Calf",
                                   "groin, knee, ankle": "Multiple",
                                   "Shoulder, Finger": "Multiple",
                                   "Bicep":"Biceps",
                                   "right Elbow": "Elbow",
                                   "Core": "Core Muscle",
                                   "Core Muscle Injury": "Core Muscle",
                                   "Right Collarbone": "Collarbone",
                                   "Medical Illness":"Illness",
                                   "left Wrist": "Wrist",
                                   "right Hamstring":"Hamstring",
                                   "Triceps":"Triceps",
                                   "right Hip":"Hip",
                                   "oblique": "Oblique"}, inplace=True)

# %%
# Actualizamos el nomnbre de dos equipos a fecha de hoy
injuries["Team"].replace({"SD":"LAC",
                          "STL":"LA",
                          "OAK":"LV",}
                         , inplace=True)

# %%
# Comprobamos el estado de nuestro dataset

injuries.iloc[[7]]
# Out:
#       Year Season Team  Week    Position         Player report_primary_injury  \
# 20  2010.0    REG  BUF   1.0  Linebacker  Reggie Torbor                 Chest
#
#    report_status practice_primary_injury                  practice_status
# 20           Out                   Chest  Did Not Participate In Practice

# %%
# Procedemos dejarlo con índice correcto

injuries.reset_index(drop=True, inplace=True)

# %% [markdown]
# ###  **Análisis univariante**
#
# Como podemos observar nuestros datasets fudamentalmente se caracterizan por ser de tipo categórico. Procedemos a valorar.

# %% [markdown]
# -   Primer dataset:

# %%
pos_rank = ranks_nfl["Position"].value_counts()
print(pos_rank)
# Out:
# Wide receiver       166
# Quarterback         140
# Linebacker          134
# Running back        111
# Defensive end       106
# Cornerback           78
# Safety               62
# Defensive tackle     62
# Tight end            54
# Offensive tackle     49
# Guard                25
# Center               12
# Kicker                1
# Name: Position, dtype: int64

# %%
# Hacemos una pequeña visualización

pos_rank.plot(kind='bar', title= "Ranking total por posición");

# %% [markdown]
# -   Segundo dataset:

# %%
# Visualizacion 
period = injuries[["Week"]].value_counts()
print(period)
# Out:
# Week
# 3.0     849
# 5.0     840
# 4.0     826
# 13.0    804
# 6.0     796
# 7.0     796
# 14.0    794
# 17.0    785
# 12.0    779
# 15.0    778
# 11.0    723
# 8.0     716
# 2.0     708
# 10.0    698
# 9.0     693
# 16.0    682
# 1.0     544
# dtype: int64

# %%
plt.figure(figsize=(12, 4))
period.plot(kind='bar', title= "Lesionados por semanas");

# %%
# Describe entre los años y las posiciones
cross_tab = pd.crosstab(index = injuries.Year, columns=injuries.Position)
cross_tab_matrix = np.array(cross_tab)
describe = cross_tab.describe()
describe
# Out:
# Position     Center  Cornerback  Defense end  Defensive tackle    Guard  \
# count     10.000000   10.000000    10.000000         10.000000  10.0000
# mean      33.600000  165.100000   101.100000         85.500000  71.4000
# std       11.276327   15.088259    12.810152         14.183324  10.6479
# min       21.000000  140.000000    85.000000         69.000000  57.0000
# 25%       25.000000  157.750000    90.250000         75.250000  61.5000
# 50%       30.500000  165.500000   100.500000         80.500000  72.5000
# 75%       38.000000  177.500000   108.250000         97.750000  81.7500
# max       57.000000  185.000000   124.000000        110.000000  83.0000
#
# Position     Kicker  Kicker returner  Linebacker  Long snapper  \
# count     10.000000        10.000000   10.000000     10.000000
# mean       8.500000         0.300000  194.700000      2.100000
# std        5.212165         0.674949   33.770632      2.024846
# min        0.000000         0.000000  151.000000      0.000000
# 25%        6.000000         0.000000  165.250000      1.000000
# 50%        7.000000         0.000000  199.500000      1.500000
# 75%       11.250000         0.000000  215.000000      2.000000
# max       17.000000         2.000000  247.000000      7.000000
#
# Position  Offensive tackle  Punt returner     Punter  Quarterback  \
# count            10.000000      10.000000  10.000000    10.000000
# mean            102.200000       0.100000   2.900000    37.100000
# std              17.586611       0.316228   2.024846    12.653063
# min              76.000000       0.000000   0.000000    22.000000
# 25%              87.750000       0.000000   1.250000    28.750000
# 50%             101.000000       0.000000   3.000000    34.500000
# 75%             118.250000       0.000000   4.000000    39.750000
# max             124.000000       1.000000   7.000000    59.000000
#
# Position  Running back      Safety   Tight end  Wide receiver
# count        10.000000   10.000000   10.000000      10.000000
# mean        117.300000  111.700000   86.000000     161.500000
# std          19.362335   12.311241   14.368175      25.211329
# min          85.000000   93.000000   62.000000     124.000000
# 25%         104.250000  104.000000   75.250000     145.250000
# 50%         120.500000  108.000000   85.000000     155.500000
# 75%         129.500000  120.750000   97.750000     179.500000
# max         143.000000  133.000000  105.000000     203.000000

# %%
viz_describe = describe.plot(kind='bar', stacked=True, alpha=0.4, width=0.8, figsize=(11, 9),)
viz_describe.legend(loc='upper center', bbox_to_anchor=(1.1, 1));

# %% [markdown]
# ###  **Análisis bivariante**
#
# Empezamos a buscar relaciones en nuestros dataset

# %% [markdown]
# > ¿Cual es la relacion entre el exito y las lesiones de la carrera de un jugador?

# %%
injuries[injuries["Player"]=="Peyton Manning"]
# Out:
#         Year Season Team  Week     Position          Player  \
# 1326  2011.0    REG  IND   1.0  Quarterback  Peyton Manning
# 1401  2011.0    REG  IND   2.0  Quarterback  Peyton Manning
# 1485  2011.0    REG  IND   3.0  Quarterback  Peyton Manning
# 1582  2011.0    REG  IND   4.0  Quarterback  Peyton Manning
# 1667  2011.0    REG  IND   5.0  Quarterback  Peyton Manning
# 1757  2011.0    REG  IND   6.0  Quarterback  Peyton Manning
# 1834  2011.0    REG  IND   7.0  Quarterback  Peyton Manning
# 1910  2011.0    REG  IND   8.0  Quarterback  Peyton Manning
# 1975  2011.0    REG  IND   9.0  Quarterback  Peyton Manning
# 2059  2011.0    REG  IND  10.0  Quarterback  Peyton Manning
# 2226  2011.0    REG  IND  12.0  Quarterback  Peyton Manning
# 2314  2011.0    REG  IND  13.0  Quarterback  Peyton Manning
# 2393  2011.0    REG  IND  14.0  Quarterback  Peyton Manning
# 2479  2011.0    REG  IND  15.0  Quarterback  Peyton Manning
# 2557  2011.0    REG  IND  16.0  Quarterback  Peyton Manning
# 2633  2011.0    REG  IND  17.0  Quarterback  Peyton Manning
# 7252  2015.0    REG  DEN  11.0  Quarterback  Peyton Manning
# 7328  2015.0    REG  DEN  12.0  Quarterback  Peyton Manning
# 7415  2015.0    REG  DEN  13.0  Quarterback  Peyton Manning
# 7510  2015.0    REG  DEN  14.0  Quarterback  Peyton Manning
# 7598  2015.0    REG  DEN  15.0  Quarterback  Peyton Manning
# 7676  2015.0    REG  DEN  16.0  Quarterback  Peyton Manning
#
#      report_primary_injury report_status practice_primary_injury  \
# 1326                  Neck           Out                    Neck
# 1401                  Neck           Out                    Neck
# 1485                  Neck           Out                    Neck
# 1582                  Neck           Out                    Neck
# 1667                  Neck           Out                    Neck
# 1757                  Neck           Out                    Neck
# 1834                  Neck           Out                    Neck
# 1910                  Neck           Out                    Neck
# 1975                  Neck           Out                    Neck
# 2059                  Neck           Out                    Neck
# 2226                  Neck           Out                    Neck
# 2314                  Neck           Out                    Neck
# 2393                  Neck           Out                    Neck
# 2479                  Neck           Out                    Neck
# 2557                  Neck           Out                    Neck
# 2633                  Neck           Out                    Neck
# 7252                  Foot           Out                    Foot
# 7328                  Foot           Out                    Foot
# 7415                  Foot           Out                    Foot
# 7510                  Foot           Out                    Foot
# 7598                  Foot           Out                    Foot
# 7676                  Foot           Out                    Foot
#
#                       practice_status
# 1326   Out (Definitely Will Not Play)
# 1401   Out (Definitely Will Not Play)
# 1485   Out (Definitely Will Not Play)
# 1582   Out (Definitely Will Not Play)
# 1667   Out (Definitely Will Not Play)
# 1757   Out (Definitely Will Not Play)
# 1834   Out (Definitely Will Not Play)
# 1910   Out (Definitely Will Not Play)
# 1975   Out (Definitely Will Not Play)
# 2059   Out (Definitely Will Not Play)
# 2226   Out (Definitely Will Not Play)
# 2314   Out (Definitely Will Not Play)
# 2393   Out (Definitely Will Not Play)
# 2479   Out (Definitely Will Not Play)
# 2557   Out (Definitely Will Not Play)
# 2633   Out (Definitely Will Not Play)
# 7252  Did Not Participate In Practice
# 7328  Did Not Participate In Practice
# 7415  Did Not Participate In Practice
# 7510  Did Not Participate In Practice
# 7598  Did Not Participate In Practice
# 7676  Did Not Participate In Practice

# %%
# Lesiones de pyton manning
Manning = ranks_nfl[ranks_nfl["Player"]=="Peyton Manning"]
Manning
# Out:
#      Rank          Player     Position    Year
# 1       2  Peyton Manning  Quarterback  2010.0
# 149    50  Peyton Manning  Quarterback  2011.0
# 201     2  Peyton Manning  Quarterback  2012.0
# 300     1  Peyton Manning  Quarterback  2013.0
# 404     5  Peyton Manning  Quarterback  2014.0

# %% [markdown]
# > ¿En qué epoca del año los jugadores se lesionan más?

# %%
week_period = pd.crosstab(index=injuries.Week, columns=injuries.Position)
matrix_periods = np.array(periods)

fig, ax = plt.subplots()

for i in range(matrix_periods.shape[1]):
    if i == 0:
        ax.bar(periods.index, matrix_periods[:, i], label=periods.columns[i])
    else:
        ax.bar(periods.index, matrix_periods[:, i], bottom=np.sum(matrix_periods[:, :i], axis=1), label=periods.columns[i])

ax.set_xlabel('Semana')
ax.set_ylabel('Número de lesiones')
ax.set_title('Lesiones por posición y semana')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1));

# %% [markdown]
# Como podemos observar la tendencia

# %%
# Crear tabla cruzada
week_period = pd.crosstab(index=injuries.Week, columns=injuries.Position)

# Sumar el número de lesiones por posición
total_injuries_by_position = week_period.sum(axis=0)

# Ordenar de mayor a menor y obtener la posición con más lesiones
most_injured_position = total_injuries_by_position.sort_values(ascending=False).index[0]

print(f"La posición que más se lesiona es {most_injured_position}")

total_injuries_by_position.plot(kind='bar', xlabel='Posición', ylabel='Número de lesiones', title='Total de lesiones por posición');
# Out:
# La posición que más se lesiona es Linebacker

# %%
# Contar el número de lesiones por jugador
injuries_by_player = injuries['Player'].value_counts()

# Obtener los 100 jugadores con más lesiones
top_100_injured_players = injuries_by_player.head(100)

print(top_100_injured_players)

#Hacemos una visualizacion
plt.figure(figsize=(18,6))
top_100_injured_players.plot(kind='bar', xlabel='Jugador', ylabel='Número de lesiones', title='Top 100 jugadores con más lesiones')

plt.xticks(rotation=85)
plt.show()
# Out:
# Eddie Royal        33
# Louis Delmas       31
# Jordan Reed        27
# Marcus Gilbert     26
# A.J. Green         25
#                    ..
# Duane Brown        13
# Adrian Peterson    13
# Tyler Eifert       13
# Shawn Lauvao       13
# Kyle Rudolph       13
# Name: Player, Length: 100, dtype: int64

# %%
# Contar el número de lesiones por jugador
injuries_by_player = injuries['Player'].value_counts()

# Seleccionar el jugador con el número máximo de lesiones
most_injured_player = injuries_by_player.idxmax()

print(f"El jugador que más se ha lesionado es {most_injured_player}. Ha estado casi 2 años fuera del terreno de juego")
# Out:
# El jugador que más se ha lesionado es Eddie Royal. Ha estado casi 2 años fuera del terreno de juego

# %% [markdown]
# #### Procedemos a intentar averiguar si hay dentro de nuestro top 100 de lesionados top 100 en los rankings

# %%
# cambiamos nuestra Serie a formato dataframe
top_100_injured_players = top_100_injured_players.to_frame()

# Hacemos un reset para tener nuevo indice generar una columna llamada "Player"
top_100_injured_players.reset_index(inplace=True)

# renombramos nuestras columnas
top_100_injured_players.rename(columns={"index":"Player", "Player":"Times"}, inplace=True)

#Hacemos una máscara para averiguar si exiten coincidencias
mascara = ranks_nfl['Player'].isin(top_100_injured_players['Player'])

# Numero de veces han coincido que un jugador ha estado dentro del top 100
injury_top = mascara.sum()

print(f"El número de veces que jugadores dentro del top 100 lesionados hay aparecido en el top 100 de los mejores es de: {injury_top} ")
# Out:
# El número de veces que jugadores dentro del top 100 lesionados hay aparecido en el top 100 de los mejores es de: 126

# %%
# Out:
# 126

# %%
media_pos = cross_tab.describe()
media_pos
# Out:
# Position     Center  Cornerback  Defense end  Defensive tackle      Guard  \
# count     17.000000   17.000000    17.000000         17.000000  17.000000
# mean      19.764706   97.117647    59.470588         50.294118  42.000000
# std        4.023826   12.673212     8.839667          8.900595   5.645795
# min        9.000000   72.000000    43.000000         35.000000  27.000000
# 25%       18.000000   90.000000    53.000000         44.000000  40.000000
# 50%       21.000000   99.000000    61.000000         51.000000  43.000000
# 75%       22.000000  107.000000    67.000000         54.000000  46.000000
# max       25.000000  119.000000    72.000000         67.000000  50.000000
#
# Position    Kicker  Kicker returner  Linebacker  Long snapper  \
# count     17.00000        17.000000   17.000000     17.000000
# mean       5.00000         0.176471  114.529412      1.235294
# std        2.09165         0.392953   15.395282      1.393261
# min        2.00000         0.000000   84.000000      0.000000
# 25%        4.00000         0.000000  106.000000      0.000000
# 50%        5.00000         0.000000  118.000000      1.000000
# 75%        6.00000         0.000000  125.000000      2.000000
# max        9.00000         1.000000  137.000000      4.000000
#
# Position  Offensive tackle  Punt returner     Punter  Quarterback  \
# count            17.000000      17.000000  17.000000    17.000000
# mean             60.117647       0.058824   1.705882    21.823529
# std               8.014692       0.242536   1.723539     5.592800
# min              51.000000       0.000000   0.000000    12.000000
# 25%              55.000000       0.000000   0.000000    18.000000
# 50%              57.000000       0.000000   1.000000    22.000000
# 75%              63.000000       0.000000   3.000000    26.000000
# max              85.000000       1.000000   5.000000    33.000000
#
# Position  Running back     Safety  Tight end  Wide receiver
# count        17.000000  17.000000  17.000000      17.000000
# mean         69.000000  65.705882  50.588235      95.000000
# std          11.958261   9.524736   9.925087      14.555927
# min          43.000000  51.000000  27.000000      61.000000
# 25%          63.000000  59.000000  44.000000      88.000000
# 50%          69.000000  62.000000  51.000000      94.000000
# 75%          75.000000  71.000000  58.000000     102.000000
# max          87.000000  83.000000  64.000000     125.000000

# %% [markdown]
# ##### ***3. Fuentes***<a id='4'></a>
# - Datasets: injuries: [Libreria NFL]("https://pypi.org/project/nfl-data-py/"), [Wikipedia]("https://en.wikipedia.org/wiki/NFL_Top_100")

# %% [markdown]
# ## <a href ='#0'> 🔝 To the moon 🔝 </a>
